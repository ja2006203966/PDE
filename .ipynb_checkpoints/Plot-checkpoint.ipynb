# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.Space import Space
from src.Grid import Gradient

# %%
np.reshape(np.array(1), (1,1,1))
# Out:
# array([[[1]]])

# %%
def func(a):
    x, y, z = a[:,:,:,0], a[:,:,:,1], a[:,:,:,2]
    res = np.sin(x)*np.sin(y)*np.sin(z)
#     res = np.expand_dims(res, axis =-1)
#     res = np.sin(a)**2
#     shape = a.shape
#     x = a.take(np.arange(shape[n]-1, shape[n]), axis=n)
    res = np.expand_dims(res, axis = -1)
    res = np.tile(res, (1,1,1,3))
    return res

# %%
x, y, z = (0,4*np.pi), (-2*np.pi,2*np.pi), (0,4*np.pi)
sp = [x,y,z]
sp = Space(sp, bins= (32,32,32))
space = sp.to_numpy()
grid = Gradient(func, sp)
cas = grid.Catesian()
# Out:
# grid shape (32, 32, 32, 3)

# %%
np.linspace(*(0,4*np.pi), num=32)
# Out:
# array([ 0.        ,  0.40536679,  0.81073359,  1.21610038,  1.62146718,
#         2.02683397,  2.43220076,  2.83756756,  3.24293435,  3.64830115,
#         4.05366794,  4.45903473,  4.86440153,  5.26976832,  5.67513512,
#         6.08050191,  6.4858687 ,  6.8912355 ,  7.29660229,  7.70196909,
#         8.10733588,  8.51270267,  8.91806947,  9.32343626,  9.72880306,
#        10.13416985, 10.53953664, 10.94490344, 11.35027023, 11.75563703,
#        12.16100382, 12.56637061])

# %%
b = 
b.take(np.arange(1,1), axis = -1)
# Out:
#   File "<ipython-input-5-70fc682cb449>", line 1
#     b =
#         ^
# SyntaxError: invalid syntax

# %%
np.arange(1,1)
# Out:
# array([], dtype=int64)

# %%
cas.shape, space.shape
# Out:
# ((32, 32, 32, 0), (32, 32, 32, 3))

# %%
np.concatenate((np.array([[1], [1]]),np.array([[2], [2]]),np.array([[3], [3]])), axis=-1 )
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
fig = plt.figure(figsize = (16,16))
ax = fig.gca(projection='3d')
ax = fig.gca()
x, y, z =  space[:,:,:,0], space[:,:,:,1], space[:,:,:,2]
u, v, w = cas[:,:,:,0], cas[:,:,:,1], cas[:,:,:,2]
ax.quiver(x, y, z, u, v, w, length=0.8, alpha=0.1)
# x, y = x[:,:,0], y[:,:,0]
# u, v = u[:,:,0], v[:,:,0]
# ax.quiver(x, y, u, v)
# j = 10
# x, z = x[:,j,:], z[:,j,:]
# u, w = u[:,j,:], w[:,j,:]
# ax.quiver(x, z, u, w)


plt.show()

# %%
fig = plt.figure(figsize = (16,16))
# ax = fig.gca(projection='3d')
ax = fig.gca()
x, y, z =  space[:,:,:,0], space[:,:,:,1], space[:,:,:,2]
u, v, w = cas[:,:,:,0], cas[:,:,:,1], cas[:,:,:,2]
# ax.quiver(x, y, z, u, v, w, length=0.4, alpha=0.1)
x, y = x[:,:,10], y[:,:,10]
u, v = u[:,:,10], v[:,:,10]
ax.quiver(x, y, u, v)
# j = 10
# x, z = x[:,j,:], z[:,j,:]
# u, w = u[:,j,:], w[:,j,:]
# ax.quiver(x, z, u, w)


plt.show()

# %%
def test(a):
    a[2]*2

# %%
a = np.array([0,1,2,3,4])
# Out:
# False

# %%
str(asdasd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e446954305cb> in <module>
# ----> 1 str(asdasd)
#
# NameError: name 'asdasd' is not defined

# %%
space[:,:,:,2]
# Out:
# array([[[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]],
#
#        [[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]],
#
#        [[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]],
#
#        ...,
#
#        [[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]],
#
#        [[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]],
#
#        [[ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         ...,
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061],
#         [ 0.        ,  0.40536679,  0.81073359, ..., 11.75563703,
#          12.16100382, 12.56637061]]])
