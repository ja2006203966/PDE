# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.Space import Space
from src.Grid import Gradient

# %%
def func(x):
    return np.sin(x)

# %%
x, y, z = (0,np.pi), (-np.pi,np.pi), (0,2*np.pi)
sp = [x,y,z]
sp = Space(sp, bins= (6,6,6))
space = sp.to_numpy()
grid = Gradient(func, sp)
cas = grid.Catesian()

# %%
cas.shape, space.shape
# Out:
# ((32, 32, 32, 3), (32, 32, 32, 3))

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z =  space[:,:,:,0], space[:,:,:,1], space[:,:,:,2]
u, v, w = cas[:,:,:,0], cas[:,:,:,1], cas[:,:,:,2]
ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
